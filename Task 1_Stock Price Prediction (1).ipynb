# %% [markdown]
# # Bharat Internship

# %% [markdown]
# # Task 1 : Stock Prediction

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout

import warnings
warnings.filterwarnings("ignore")

# %%
# loading the data

df= pd.read_csv(r'C:/Users/Pranjali/Desktop/bharat/Task 1_Stock Price Prediction.ipynb' , encoding= 'unicode_escape')

# %%
# Set colors

class color:    
    GREEN, RED = '\033[92m', '\033[91m'
    BOLD, UNDERLINE, END = '\033[1m', '\033[4m', '\033[0m'
    GREEN_BOLD = GREEN + BOLD
    RED_BOLD = RED + BOLD
    GREEN_BOLD_UND = GREEN_BOLD + UNDERLINE   
    
rb, gb,  = color.RED_BOLD, color.GREEN_BOLD
gbu, end = color.GREEN_BOLD_UND, color.END

# %%
df.shape
# Out:
# (5044, 7)

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 1  2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2  2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 3  2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 4  2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5044 entries, 0 to 5043
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5044 non-null   object
#  1   Open       5044 non-null   float64
#  2   High       5044 non-null   float64
#  3   Low        5044 non-null   float64
#  4   Close      5044 non-null   float64
#  5   Adj Close  5044 non-null   float64
#  6   Volume     5044 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 276.0+ KB

# %%
# Convert the type of "Date" column into date-time

df["Date"] = pd.to_datetime(df["Date"])
print (df.dtypes)
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
# Add the "Year", 'Month' and "Day" columns
df["Year"] = df["Date"].apply(lambda x : str(x)[:4])
df["Month"] = df["Date"].apply(lambda x : str(x)[5:7])
df["Day"] = df["Date"].apply(lambda x : str(x)[8:10])

df.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume  \
# 0 2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 1 2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2 2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 3 2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 4 2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200
#
#    Year Month Day
# 0  2002    05  23
# 1  2002    05  24
# 2  2002    05  28
# 3  2002    05  29
# 4  2002    05  30

# %% [markdown]
# # Feature Extraction

# %%
# Print the number of trading days
print(f'{rb}Total number of trading days: {end}{gbu}{df.shape[0]}{end}')
print(f'{rb}Total number of fields: {end}{gbu}{df.shape[1]}{end}')
print('\n')
# Check the Null and NA values
print(f'{rb}Null values: {end}{gbu}{df.isnull().values.sum()}{end}')
print(f'{rb}NA values: {end}{gbu}{df.isna().values.any()}{end}')
# Out:
# Total number of trading days: 5044
# Total number of fields: 10
#
#
# Null values: 0
# NA values: False

# %%
# Create a new dataframe with only the Open column and convert it into a NumPy array
df = df['Open'].values

# Reshape the data
df = df.reshape(-1, 1)

# %%
# Split the data into training and testing sets
dataset_train = np.array(df[:int(df.shape[0]*0.8)])
dataset_test = np.array(df[int(df.shape[0]*0.8):])

# %% [markdown]
# To produce the best-optimized results, we are required to scale the data.
#
# For this task, we are leveraging scikit-learn library’s MinMaxScaler() for converting the input values between 0 to 1.

# %%
# Scale the data 
scaler = MinMaxScaler(feature_range=(0,1))

dataset_train = scaler.fit_transform(dataset_train)
dataset_test = scaler.transform(dataset_test)

# %% [markdown]
# We will create the helper function with 50 timesteps. In other words, for the features(x) we'll append the last 50 prices, and for the label(y) we'll append the next price.
#
# After that we will convert it into a NumPy array.

# %%
# Create the function that will help us to create the datasets
def create_dataset(df):
    x = []
    y = []
    for i in range(50, df.shape[0]):
        x.append(df[i-50:i, 0]) 
        y.append(df[i, 0]) 
    x = np.array(x) 
    y = np.array(y)
    return x,y

# %%
# Create the training and testing data by calling our function for each one
x_train, y_train = create_dataset(dataset_train)
x_test, y_test = create_dataset(dataset_test)

# %%
# Reshape the data to make it a 3D array in order to use it in LSTM Layer
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# # Building Model

# %% [markdown]
# For the LSTM layer, we add 96 units that represent the dimensionality of the output space.
#
# The return_sequences parameter is set to True for returning the last output in output.
#
# For the Dropout layers, we specify the percentage of layers is 20% that should be dropped.
#
# The next step is to add the Dense layer.

# %%
model = Sequential()
model.add(LSTM(units=96, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=96, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=96, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=96))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# %%
# Summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 96)            37632
#
#  dropout (Dropout)           (None, 50, 96)            0
#
#  lstm_1 (LSTM)               (None, 50, 96)            74112
#
#  dropout_1 (Dropout)         (None, 50, 96)            0
#
#  lstm_2 (LSTM)               (None, 50, 96)            74112
#
#  dropout_2 (Dropout)         (None, 50, 96)            0
#
#  lstm_3 (LSTM)               (None, 96)                74112
#
#  dropout_3 (Dropout)         (None, 96)                0
#
#  dense (Dense)               (None, 1)                 97
#
# =================================================================
# Total params: 260065 (1015.88 KB)
# Trainable params: 260065 (1015.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Reshape the feature for the LSTM layer 
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1)) # for expecting 3 dimentions, not 2
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# We will compile the model with the help of adam optimizer.
#
# The error is computed using mean_squared_error

# %%
# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# # Training Model

# %% [markdown]
# With our model and data constructed, we can now train the model.

# %%
# Define modifiable training hyperparameters
epochs = 40
batch_size = 64 

# Save the model and start the training
model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size)
model.save('stock_prediction')
# Out:
# Epoch 1/40
# 63/63 [==============================] - 41s 389ms/step - loss: 0.0044
# Epoch 2/40
# 63/63 [==============================] - 29s 467ms/step - loss: 6.0529e-04
# Epoch 3/40
# 63/63 [==============================] - 27s 435ms/step - loss: 6.5855e-04
# Epoch 4/40
# 63/63 [==============================] - 26s 413ms/step - loss: 6.6020e-04
# Epoch 5/40
# 63/63 [==============================] - 25s 396ms/step - loss: 6.0118e-04
# Epoch 6/40
# 63/63 [==============================] - 24s 384ms/step - loss: 7.1292e-04
# Epoch 7/40
# 63/63 [==============================] - 24s 384ms/step - loss: 5.6839e-04
# Epoch 8/40
# 63/63 [==============================] - 24s 382ms/step - loss: 6.2746e-04
# Epoch 9/40
# 63/63 [==============================] - 24s 377ms/step - loss: 5.5923e-04
# Epoch 10/40
# 63/63 [==============================] - 24s 380ms/step - loss: 5.3900e-04
# Epoch 11/40
# 63/63 [==============================] - 24s 383ms/step - loss: 5.4917e-04
# Epoch 12/40
# 63/63 [==============================] - 26s 415ms/step - loss: 4.5171e-04
# Epoch 13/40
# 63/63 [==============================] - 29s 469ms/step - loss: 4.3976e-04
# Epoch 14/40
# 63/63 [==============================] - 24s 381ms/step - loss: 4.3951e-04
# Epoch 15/40
# 63/63 [==============================] - 28s 446ms/step - loss: 4.1585e-04
# Epoch 16/40
# 63/63 [==============================] - 24s 386ms/step - loss: 4.0724e-04
# Epoch 17/40
# 63/63 [==============================] - 24s 380ms/step - loss: 5.0266e-04
# Epoch 18/40
# 63/63 [==============================] - 24s 380ms/step - loss: 4.9895e-04
# Epoch 19/40
# 63/63 [==============================] - 24s 379ms/step - loss: 4.6741e-04
# Epoch 20/40
# 63/63 [==============================] - 24s 387ms/step - loss: 4.0069e-04
# Epoch 21/40
# 63/63 [==============================] - 24s 382ms/step - loss: 4.5408e-04
# Epoch 22/40
# 63/63 [==============================] - 25s 395ms/step - loss: 3.5176e-04
# Epoch 23/40
# 63/63 [==============================] - 28s 451ms/step - loss: 4.0508e-04
# Epoch 24/40
# 63/63 [==============================] - 27s 430ms/step - loss: 4.5322e-04
# Epoch 25/40
# 63/63 [==============================] - 25s 390ms/step - loss: 3.3881e-04
# Epoch 26/40
# 63/63 [==============================] - 26s 410ms/step - loss: 3.7035e-04
# Epoch 27/40
# 63/63 [==============================] - 27s 424ms/step - loss: 4.5479e-04
# Epoch 28/40
# 63/63 [==============================] - 26s 411ms/step - loss: 3.6393e-04
# Epoch 29/40
# 63/63 [==============================] - 25s 389ms/step - loss: 3.4722e-04
# Epoch 30/40
# 63/63 [==============================] - 24s 387ms/step - loss: 4.4225e-04
# Epoch 31/40
# 63/63 [==============================] - 24s 388ms/step - loss: 3.8287e-04
# Epoch 32/40
# 63/63 [==============================] - 25s 390ms/step - loss: 3.4737e-04
# Epoch 33/40
# 63/63 [==============================] - 25s 403ms/step - loss: 4.8508e-04
# Epoch 34/40
# 63/63 [==============================] - 26s 407ms/step - loss: 3.3156e-04
# Epoch 35/40
# 63/63 [==============================] - 27s 436ms/step - loss: 3.3043e-04
# Epoch 36/40
# 63/63 [==============================] - 32s 512ms/step - loss: 2.9217e-04
# Epoch 37/40
# 63/63 [==============================] - 29s 462ms/step - loss: 3.1267e-04
# Epoch 38/40
# 63/63 [==============================] - 27s 423ms/step - loss: 3.3480e-04
# Epoch 39/40
# 63/63 [==============================] - 27s 421ms/step - loss: 3.1967e-04
# Epoch 40/40
# 63/63 [==============================] - 25s 402ms/step - loss: 4.2177e-04
# INFO:tensorflow:Assets written to: stock_prediction\assets
# INFO:tensorflow:Assets written to: stock_prediction\assets

# %%
# Load the model
model = load_model('stock_prediction')

# %% [markdown]
# # Prediction Model

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 30/30 [==============================] - 5s 85ms/step

# %% [markdown]
# # Plotting Results

# %%
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(20,15))
ax.set_facecolor('#000035')
ax.plot(y_test_scaled, color='blue', linewidth=2, label='Original price')
plt.plot(predictions, color='yellow', linewidth=2.5, label='Predicted price')
plt.title('Netflix Stock Price Prediction')
plt.legend();

# %% [markdown]
# # Thankyou

# %% [markdown]
# # Presented by : Pranjali S Patil
